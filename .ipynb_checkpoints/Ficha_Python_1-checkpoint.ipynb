# %%
import pandas as pd

# %%
# 1 ler o CSV
df = pd.read_csv("Dataset_python.csv")

# %%
# 2 ver as 15 primeiras linhas
print(df.head(15))
# Out:
#                      coluna1  coluna2  coluna3  coluna4  coluna5  coluna6  \
# 0   Ait Sidi, Karthikeyan       10084        1        1        1        5
# 1          Akinkuolie, Sarah    10196        1        1        0        5
# 2               Alagbe,Trina    10088        1        1        0        1
# 3           Anderson, Carol     10069        0        2        0        5
# 4          Anderson, Linda      10002        0        0        0        1
# 5            Andreola, Colby    10194        0        0        0        1
# 6                Athwal, Sam    10062        0        4        1        1
# 7           Bachiochi, Linda    10114        0        0        0        3
# 8         Bacong, Alejandro     10250        0        2        1        1
# 9       Baczenski, Rachael      10252        1        1        0        5
# 10           Barbara, Thomas    10242        1        1        1        5
# 11          Barbossa, Hector    10012        0        2        1        1
# 12      Barone, Francesco  A    10265        0        0        1        1
# 13             Barton, Nader    10066        0        2        1        5
# 14             Bates, Norman    10061        0        0        1        4
#
#     coluna7  coluna8  coluna9  coluna10  ...         coluna27  coluna28  \
# 0         3        3        0    104437  ...       Simon Roup       4.0
# 1         5        3        0     64955  ...   Kissy Sullivan      20.0
# 2         5        3        0     64991  ...     Elijiah Gray      16.0
# 3         5        3        0     50825  ...   Webster Butler      39.0
# 4         5        4        0     57568  ...         Amy Dunn      11.0
# 5         4        3        0     95660  ...  Alex Sweetwater      10.0
# 6         5        3        0     59365  ...    Ketsia Liebig      19.0
# 7         5        3        1     47837  ...   Brannon Miller      12.0
# 8         3        3        0     50178  ...     Peter Monroe       7.0
# 9         5        3        1     54670  ...    David Stanley      14.0
# 10        5        3        1     47211  ...   Kissy Sullivan      20.0
# 11        3        4        1     92328  ...       Simon Roup       4.0
# 12        5        3        0     58709  ...    Kelley Spirea      18.0
# 13        5        3        0     52505  ...   Michael Albert      22.0
# 14        5        3        0     57834  ...    Kelley Spirea      18.0
#
#                    coluna29     coluna30  coluna31 coluna32 coluna33  \
# 0                    Indeed  Fully Meets      4.96        3        6
# 1                  LinkedIn  Fully Meets      3.02        3        0
# 2                    Indeed  Fully Meets      4.84        5        0
# 3             Google Search  Fully Meets      5.00        4        0
# 4                  LinkedIn      Exceeds      5.00        5        0
# 5                  LinkedIn  Fully Meets      3.04        3        4
# 6         Employee Referral  Fully Meets      5.00        4        0
# 7        Diversity Job Fair  Fully Meets      4.46        3        0
# 8                    Indeed  Fully Meets      5.00        5        6
# 9        Diversity Job Fair  Fully Meets      4.20        4        0
# 10       Diversity Job Fair  Fully Meets      4.20        3        0
# 11       Diversity Job Fair      Exceeds      4.28        4        5
# 12            Google Search  Fully Meets      4.60        4        0
# 13  On-line Web application  Fully Meets      5.00        5        0
# 14            Google Search  Fully Meets      5.00        4        0
#
#      coluna34 coluna35 coluna36
# 0   2/24/2016        0       17
# 1   5/15/2012        0        3
# 2    1/3/2019        0       15
# 3    2/1/2016        0        2
# 4    1/7/2019        0       15
# 5    1/2/2019        0       19
# 6   2/25/2019        0       19
# 7   1/25/2019        0        4
# 8   2/18/2019        0       16
# 9   1/30/2016        0       12
# 10   5/6/2016        0       15
# 11  2/25/2019        0        9
# 12  2/14/2019        0        7
# 13   3/2/2017        0        1
# 14   4/5/2017        0       20
#
# [15 rows x 36 columns]

# %%
# 3 Obter a dimensão do dataset
print(df.shape)
# Out:
# (310, 36)

# %%
# 4 remover a primeira linha do dataset
df.to_csv("Dataset_python.csv", index=False, header=False)
print(df.head(2))
# Out:
#                     coluna1  coluna2  coluna3  coluna4  coluna5  coluna6  \
# 0  Ait Sidi, Karthikeyan       10084        1        1        1        5
# 1         Akinkuolie, Sarah    10196        1        1        0        5
#
#    coluna7  coluna8  coluna9  coluna10  ...        coluna27  coluna28  \
# 0        3        3        0    104437  ...      Simon Roup       4.0
# 1        5        3        0     64955  ...  Kissy Sullivan      20.0
#
#    coluna29     coluna30  coluna31 coluna32 coluna33   coluna34 coluna35  \
# 0    Indeed  Fully Meets      4.96        3        6  2/24/2016        0
# 1  LinkedIn  Fully Meets      3.02        3        0  5/15/2012        0
#
#   coluna36
# 0       17
# 1        3
#
# [2 rows x 36 columns]

# %%
# 5 adicionar headers novos
n = df.shape[1]
df.columns = [f"coluna{i+1}" for i in range(n)]
df.to_csv("Dataset_python.csv", index=False)
print(df.head(2))
# Out:
#                     coluna1  coluna2  coluna3  coluna4  coluna5  coluna6  \
# 0  Ait Sidi, Karthikeyan       10084        1        1        1        5
# 1         Akinkuolie, Sarah    10196        1        1        0        5
#
#    coluna7  coluna8  coluna9  coluna10  ...        coluna27  coluna28  \
# 0        3        3        0    104437  ...      Simon Roup       4.0
# 1        5        3        0     64955  ...  Kissy Sullivan      20.0
#
#    coluna29     coluna30  coluna31 coluna32 coluna33   coluna34 coluna35  \
# 0    Indeed  Fully Meets      4.96        3        6  2/24/2016        0
# 1  LinkedIn  Fully Meets      3.02        3        0  5/15/2012        0
#
#   coluna36
# 0       17
# 1        3
#
# [2 rows x 36 columns]

# %%
# 6 apresentar o nome das colunas
print(df.columns)
# Out:
# Index(['coluna1', 'coluna2', 'coluna3', 'coluna4', 'coluna5', 'coluna6',
#        'coluna7', 'coluna8', 'coluna9', 'coluna10', 'coluna11', 'coluna12',
#        'coluna13', 'coluna14', 'coluna15', 'coluna16', 'coluna17', 'coluna18',
#        'coluna19', 'coluna20', 'coluna21', 'coluna22', 'coluna23', 'coluna24',
#        'coluna25', 'coluna26', 'coluna27', 'coluna28', 'coluna29', 'coluna30',
#        'coluna31', 'coluna32', 'coluna33', 'coluna34', 'coluna35', 'coluna36'],
#       dtype='object')

# %%
# 7 trocar o nome de uma coluna a escolha
df.rename(columns={'coluna1': 'Nome'}, inplace=True)
print(df.head(2))
# Out:
#                        Nome  coluna2  coluna3  coluna4  coluna5  coluna6  \
# 0  Ait Sidi, Karthikeyan       10084        1        1        1        5
# 1         Akinkuolie, Sarah    10196        1        1        0        5
#
#    coluna7  coluna8  coluna9  coluna10  ...        coluna27  coluna28  \
# 0        3        3        0    104437  ...      Simon Roup       4.0
# 1        5        3        0     64955  ...  Kissy Sullivan      20.0
#
#    coluna29     coluna30  coluna31 coluna32 coluna33   coluna34 coluna35  \
# 0    Indeed  Fully Meets      4.96        3        6  2/24/2016        0
# 1  LinkedIn  Fully Meets      3.02        3        0  5/15/2012        0
#
#   coluna36
# 0       17
# 1        3
#
# [2 rows x 36 columns]

# %%
# 8 trocar o nome da primeira coluna de index para indice
df.index.name = 'Indice'
print(df.head())
# Out:
#                             Nome  coluna2  coluna3  coluna4  coluna5  coluna6  \
# Indice
# 0       Ait Sidi, Karthikeyan       10084        1        1        1        5
# 1              Akinkuolie, Sarah    10196        1        1        0        5
# 2                   Alagbe,Trina    10088        1        1        0        1
# 3               Anderson, Carol     10069        0        2        0        5
# 4              Anderson, Linda      10002        0        0        0        1
#
#         coluna7  coluna8  coluna9  coluna10  ...        coluna27  coluna28  \
# Indice                                       ...
# 0             3        3        0    104437  ...      Simon Roup       4.0
# 1             5        3        0     64955  ...  Kissy Sullivan      20.0
# 2             5        3        0     64991  ...    Elijiah Gray      16.0
# 3             5        3        0     50825  ...  Webster Butler      39.0
# 4             5        4        0     57568  ...        Amy Dunn      11.0
#
#              coluna29     coluna30  coluna31 coluna32 coluna33   coluna34  \
# Indice
# 0              Indeed  Fully Meets      4.96        3        6  2/24/2016
# 1            LinkedIn  Fully Meets      3.02        3        0  5/15/2012
# 2              Indeed  Fully Meets      4.84        5        0   1/3/2019
# 3       Google Search  Fully Meets      5.00        4        0   2/1/2016
# 4            LinkedIn      Exceeds      5.00        5        0   1/7/2019
#
#        coluna35 coluna36
# Indice
# 0             0       17
# 1             0        3
# 2             0       15
# 3             0        2
# 4             0       15
#
# [5 rows x 36 columns]
